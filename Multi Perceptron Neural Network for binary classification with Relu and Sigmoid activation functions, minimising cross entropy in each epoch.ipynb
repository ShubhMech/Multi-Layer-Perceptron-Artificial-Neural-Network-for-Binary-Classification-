# %%
import sklearn

# %%
import matplotlib.pyplot as plt, seaborn as sns

# %%
import tensorflow.keras as keras

# %%
from keras.models import Sequential as seq

# %%
from keras.layers import Dense as dense

# %%
from sklearn import datasets

# %%
data=datasets.make_moons(n_samples=15000,noise=0.05)

# %%
X,y= data

# %%
X
# Out:
# array([[ 1.77075667, -0.10564069],
#        [ 0.33700401, -0.33724746],
#        [ 0.07012682, -0.06055028],
#        ...,
#        [-0.82945337,  0.70730174],
#        [-0.63214393,  0.75598587],
#        [ 0.48703266, -0.31564577]])

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 1], dtype=int64)

# %%
sns.scatterplot(X[:,0],X[:,1], hue=y)
# Out:
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
model1= seq()

# %%
import pandas as pd
df1=pd.DataFrame(X)

# %%
df1
# Out:
#               0         1
# 0      1.770757 -0.105641
# 1      0.337004 -0.337247
# 2      0.070127 -0.060550
# 3      0.841606  0.670343
# 4      0.576645  0.792589
# ...         ...       ...
# 14995  0.145488  0.988798
# 14996  0.916874  0.332787
# 14997 -0.829453  0.707302
# 14998 -0.632144  0.755986
# 14999  0.487033 -0.315646
#
# [15000 rows x 2 columns]

# %%
df1.describe()
# Out:
#                   0             1
# count  15000.000000  15000.000000
# mean       0.499210      0.249822
# std        0.868643      0.496498
# min       -1.167065     -0.637956
# 25%       -0.048501     -0.206627
# 50%        0.498408      0.250364
# 75%        1.047236      0.706468
# max        2.126032      1.127371

# %%
df1.head()
# Out:
#           0         1
# 0  1.770757 -0.105641
# 1  0.337004 -0.337247
# 2  0.070127 -0.060550
# 3  0.841606  0.670343
# 4  0.576645  0.792589

# %%
X[:,0].mean()
# Out:
# 0.49920988823642226

# %%
X[:,1].mean()
# Out:
# 0.24982175849456695

# %%
X[:,0]=X[:,0]-X[:,0].mean()

# %%
X[:,0]=X[:,0]/X[:,0].max()

# %%
X[:,0]
# Out:
# array([ 0.78161403, -0.09970722, -0.26375541, ..., -0.81672326,
#        -0.69543805, -0.00748529])

# %%
X[:,1]=X[:,1]-X[:,1].mean()

# %%
X[:,1]=X[:,1]/X[:,1].max()

# %%
X[:,1]
# Out:
# array([-0.40506253, -0.66898697, -0.35368036, ...,  0.52131527,
#         0.57679262, -0.64437106])

# %%
X
# Out:
# array([[ 0.78161403, -0.40506253],
#        [-0.09970722, -0.66898697],
#        [-0.26375541, -0.35368036],
#        ...,
#        [-0.81672326,  0.52131527],
#        [-0.69543805,  0.57679262],
#        [-0.00748529, -0.64437106]])

# %%
df=pd.DataFrame(X)

# %%
df
# Out:
#               0         1
# 0      0.781614 -0.405063
# 1     -0.099707 -0.668987
# 2     -0.263755 -0.353680
# 3      0.210470  0.479200
# 4      0.047599  0.618503
# ...         ...       ...
# 14995 -0.217431  0.842091
# 14996  0.256736  0.094541
# 14997 -0.816723  0.521315
# 14998 -0.695438  0.576793
# 14999 -0.007485 -0.644371
#
# [15000 rows x 2 columns]

# %%
df.describe()
# Out:
#                   0             1
# count  1.500000e+04  1.500000e+04
# mean   1.113184e-17  3.019807e-17
# std    5.339506e-01  5.657778e-01
# min   -1.024252e+00 -1.011656e+00
# 25%   -3.366751e-01 -5.201397e-01
# 50%   -4.926476e-04  6.178467e-04
# 75%    3.368691e-01  5.203647e-01
# max    1.000000e+00  1.000000e+00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       15000 non-null  float64
#  1   1       15000 non-null  float64
# dtypes: float64(2)
# memory usage: 234.5 KB

# %%
from sklearn.model_selection import train_test_split as tts

# %%
X_train,X_test,y_train,y_test=tts(X,y,test_size=0.3)

# %%
sns.scatterplot(X_train[:,0],X_train[:,1], hue=y_train)
# Out:
# C:\Users\Asus\anaconda31\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
model1.add(dense(1,input_dim=2, activation='sigmoid'))

# %%
model1.compile(optimizer='adam', loss='binary_crossentropy')

# %%
model1.fit(X_train,y_train,epochs=100
          )
# Out:
# Epoch 1/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 2/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 3/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 4/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 5/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 6/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 7/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 8/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 9/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 10/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 11/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 12/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 13/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 14/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 15/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 16/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 17/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 18/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 19/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 20/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 21/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 22/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 23/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 24/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 25/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 26/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 27/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 28/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 29/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 30/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 31/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 32/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 33/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 34/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 35/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 36/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 37/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 38/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 39/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 40/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 41/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 42/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 43/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 44/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 45/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 46/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 47/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 48/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 49/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 50/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 51/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 52/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 53/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 54/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 55/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 56/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 57/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 58/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 59/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 60/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 61/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 62/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 63/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 64/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 65/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 66/100
# 329/329 [==============================] - 1s 3ms/step - loss: 0.2393A: 0s - l
# Epoch 67/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 68/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 69/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393A: 0s - loss: 0.2
# Epoch 70/100
# 329/329 [==============================] - 1s 3ms/step - loss: 0.2393
# Epoch 71/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 72/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 73/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 74/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 75/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 76/100
# 329/329 [==============================] - 1s 3ms/step - loss: 0.2393
# Epoch 77/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 78/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 79/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 80/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 81/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 82/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 83/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 84/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 85/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 86/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 87/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 88/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 89/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 90/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 91/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 92/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 93/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 94/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 95/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 96/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 97/100
# 329/329 [==============================] - 1s 3ms/step - loss: 0.2393
# Epoch 98/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 99/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393
# Epoch 100/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.2393

# %%
y_pred=model1.predict(X_test)

# %%
from sklearn.metrics import classification_report as cvs, confusion_matrix as cm

# %%
y_pred
# Out:
# array([[0.02677259],
#        [0.9957446 ],
#        [0.995017  ],
#        ...,
#        [0.00342235],
#        [0.01994631],
#        [0.00715664]], dtype=float32)

# %%
y_pred=[1 if y_pred[i]>0.5 else 0 for i in range(len(y_pred))]

# %%
sns.heatmap(cm(y_test,y_pred), annot=True ,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
report=cvs(y_test,y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89      2229
#            1       0.89      0.89      0.89      2271
#
#     accuracy                           0.89      4500
#    macro avg       0.89      0.89      0.89      4500
# weighted avg       0.89      0.89      0.89      4500

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = X_train, y_train

X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() , stop = X_set[:, 0].max(), step = 0.01),
                     np.arange(start = X_set[:, 1].min(), stop = X_set[:, 1].max(), step = 0.01))
plt.contourf(X1, X2, model1.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
    
plt.title('Training Classification Results')
plt.xlabel('1-Distance from Bump')
plt.ylabel('Height of Bump')
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
model2=seq()
model2.add(dense(20,input_dim=2, activation='relu'))
model2.add(dense(20, activation='relu'))
model2.add(dense(20, activation='relu'))
model2.add(dense(1, activation='sigmoid'))

# %%
model2.compile(optimizer='adam', loss='binary_crossentropy')

# %%
model2.fit(X_train,y_train,epochs=100
          )
# Out:
# Epoch 1/100
# 329/329 [==============================] - 2s 2ms/step - loss: 0.3013
# Epoch 2/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.0323
# Epoch 3/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.0037
# Epoch 4/100
# 329/329 [==============================] - 1s 2ms/step - loss: 0.0013
# Epoch 5/100
# 329/329 [==============================] - 1s 2ms/step - loss: 6.0370e-04
# Epoch 6/100
# 329/329 [==============================] - 1s 2ms/step - loss: 3
100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0221e-05
# Epoch 61/100
# 329/329 [==============================] - 1s 3ms/step - loss: 3.7234e-07
# Epoch 62/100
# 329/329 [==============================] - 1s 3ms/step - loss: 5.8302e-08
# Epoch 63/100
# 329/329 [==============================] - 1s 4ms/step - loss: 3.9280e-08A: 0s - los
# Epoch 64/100
# 329/329 [==============================] - 1s 2ms/step - loss: 3.0114e-08
# Epoch 65/100
# 329/329 [==============================] - 1s 3ms/step - loss: 2.4048e-08
# Epoch 66/100
# 329/329 [==============================] - 1s 3ms/step - loss: 2.0258e-08
# Epoch 67/100
# 329/329 [==============================] - 1s 4ms/step - loss: 1.7323e-08
# Epoch 68/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.5014e-08
# Epoch 69/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.3075e-08
# Epoch 70/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1372e-08
# Epoch 71/100
# 329/329 [==============================] - 1s 3ms/step - loss: 9.9711e-09
# Epoch 72/100
# 329/329 [==============================] - 1s 3ms/step - loss: 8.8193e-09
# Epoch 73/100
# 329/329 [==============================] - 1s 3ms/step - loss: 7.8326e-09
# Epoch 74/100
# 329/329 [==============================] - 1s 2ms/step - loss: 6.9925e-09
# Epoch 75/100
# 329/329 [==============================] - 1s 3ms/step - loss: 6.2428e-09
# Epoch 76/100
# 329/329 [==============================] - 1s 3ms/step - loss: 5.5927e-09
# Epoch 77/100
# 329/329 [==============================] - 1s 3ms/step - loss: 5.0346e-09
# Epoch 78/100
# 329/329 [==============================] - 1s 3ms/step - loss: 4.5025e-09
# Epoch 79/100
# 329/329 [==============================] - 1s 2ms/step - loss: 4.0381e-09
# Epoch 80/100
# 329/329 [==============================] - 1s 2ms/step - loss: 3.6673e-09
# Epoch 81/100
# 329/329 [==============================] - 1s 3ms/step - loss: 3.3392e-09
# Epoch 82/100
# 329/329 [==============================] - 1s 3ms/step - loss: 3.0381e-09
# Epoch 83/100
# 329/329 [==============================] - 1s 3ms/step - loss: 2.7967e-09
# Epoch 84/100
# 329/329 [==============================] - 1s 3ms/step - loss: 2.5947e-09
# Epoch 85/100
# 329/329 [==============================] - 1s 2ms/step - loss: 2.4025e-09
# Epoch 86/100
# 329/329 [==============================] - 1s 2ms/step - loss: 2.2496e-09
# Epoch 87/100
# 329/329 [==============================] - 1s 2ms/step - loss: 2.1044e-09
# Epoch 88/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.9652e-09
# Epoch 89/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.8575e-09
# Epoch 90/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.7442e-09
# Epoch 91/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.7273e-09
# Epoch 92/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.5369e-09
# Epoch 93/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.4265e-09
# Epoch 94/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.3315e-09
# Epoch 95/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.2580e-09A: 0s - loss: 1.
# Epoch 96/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1816e-09
# Epoch 97/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.0908e-09
# Epoch 98/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.0203e-09
# Epoch 99/100
# 329/329 [==============================] - 1s 2ms/step - loss: 9.6094e-10
# Epoch 100/100
# 329/329 [==============================] - 1s 2ms/step - loss: 8.9951e-10

# %%
y_pred= model2.predict(X_test)

# %%
y_pred=[1 if y_pred[i]>0.5 else 0 for i in range(len(y_pred))]

# %%
sns.heatmap(cm(y_test,y_pred), annot=True ,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
report=cvs(y_test,y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2229
#            1       1.00      1.00      1.00      2271
#
#     accuracy                           1.00      4500
#    macro avg       1.00      1.00      1.00      4500
# weighted avg       1.00      1.00      1.00      4500

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = X_train, y_train

X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() , stop = X_set[:, 0].max(), step = 0.01),
                     np.arange(start = X_set[:, 1].min(), stop = X_set[:, 1].max(), step = 0.01))
plt.contourf(X1, X2, model2.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
    
plt.title('Training Classification Results')
plt.xlabel('1-Distance from Bump')
plt.ylabel('Height of Bump')
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
